# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Setup check complete!")
# Out:
# Setup check complete!
# np.float64(2.5)

# %%
#Create array and calculate mean
arr = np.array([1, 2, 3, 4])
arr.mean()
# Out:
# np.float64(2.5)

# %%
#Create a small DataFrame
data = pd.DataFrame({
    "Stock": ["AAPL", "MSFT", "GOOG"],
    "Price": [220, 330, 280]
})
data
# Out:
#   Stock  Price
# 0  AAPL    220
# 1  MSFT    330
# 2  GOOG    280

# %%
#Plot a basic chart
plt.plot([1,2,3], [1,4,9])
plt.title("Sample Plot")
plt.show()
